# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df= pd.read_csv('Air Passengers.csv')

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
pd.Period('2023',freq='d')
# Out:
# Period('2023-01-01', 'D')

# %%
pd.to_datetime('1949-01')
# Out:
# Timestamp('1949-01-01 00:00:00')

# %%
plt.figure(figsize=(10,10))
plt.plot(df['Month'],df['#Passengers'])

# %%
df.shape
# Out:
# (144, 2)

# %%
df.set_index('Month',inplace=True)
df.index=pd.to_datetime(df.index)
df.dropna(inplace=True)
df.plot()
#df.index
# Out:
# <Axes: xlabel='Month'>

# %%
model=seasonal_decompose(df['#Passengers'],model='multiplicative')

# %%
model.trend.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
model.seasonal.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
model.resid.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
ts_data_log=np.log(df['#Passengers'])

# %%
ts_data_log.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
ts_data_log
# Out:
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# 1949-04-01    4.859812
# 1949-05-01    4.795791
#                 ...
# 1960-08-01    6.406880
# 1960-09-01    6.230481
# 1960-10-01    6.133398
# 1960-11-01    5.966147
# 1960-12-01    6.068426
# Name: #Passengers, Length: 144, dtype: float64

# %%
pd.DataFrame
