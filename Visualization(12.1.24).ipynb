# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
x=[1,2,3,4,5]
y=[10,20,35,45,60]

# %%
fig=plt.figure(figsize=(10,10),facecolor='lightgreen')
plt.title('Python Visualization',color='red',size=20)
fig.add_subplot(2,3,5)
plt.scatter(x,y,color='red',marker='<')
plt.plot(x,y,color='green',linewidth=2,linestyle=':')
plt.xlabel('X_LABEL',color='black',size=15)
plt.ylabel('Y_LABEL',color='black',size=15)
#plt.title('Python Visualization',color='red',size=20)
plt.xticks(np.arange(0,10,2))
plt.yticks(np.arange(0,70,10))
fig.add_subplot(2,3,1)
plt.scatter(x,y,color='red',marker='<')
plt.plot(x,y,color='green',linewidth=2,linestyle=':')
plt.xlabel('X_LABEL',color='black',size=15)
plt.ylabel('Y_LABEL',color='black',size=15)
#plt.title('Python Visualization',color='red',size=20)
plt.xticks(np.arange(0,10,2))
plt.yticks(np.arange(0,70,10))
fig.add_subplot(2,3,3)
plt.scatter(x,y,color='red',marker='<')
plt.plot(x,y,color='green',linewidth=2,linestyle=':')
plt.xlabel('X_LABEL',color='black',size=15)
plt.ylabel('Y_LABEL',color='black',size=15)
plt.xticks(np.arange(0,10,2))
plt.yticks(np.arange(0,70,10));

# %%
df= pd.read_csv('diamonds.csv')

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.size
# Out:
# 539400

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df['color'].value_counts().plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='color'>

# %%
df_color=pd.crosstab(index=df['color'],columns='count')
df_color
# Out:
# col_0  count
# color
# D       6775
# E       9797
# F       9542
# G      11292
# H       8304
# I       5422
# J       2808

# %%
a=df_color.plot(kind='bar',color='red',figsize=(7,7))
a.bar_label(a.containers[0],label_type='center');

# %%
df_cut=pd.crosstab(index=df['color'],columns=df['cut'])
df_cut
# Out:
# cut    Fair  Good  Ideal  Premium  Very Good
# color
# D       163   662   2834     1603       1513
# E       224   933   3903     2337       2400
# F       312   909   3826     2331       2164
# G       314   871   4884     2924       2299
# H       303   702   3115     2360       1824
# I       175   522   2093     1428       1204
# J       119   307    896      808        678

# %%
b=df_cut.plot(kind='bar',stacked=True)
b.bar_label(b.containers[0]);

# %%
print(b.containers[0][0])
# Out:
# Rectangle(xy=(-0.25, 0), width=0.5, height=163, angle=0)

# %%
df_cut
# Out:
# cut    Fair  Good  Ideal  Premium  Very Good
# color
# D       163   662   2834     1603       1513
# E       224   933   3903     2337       2400
# F       312   909   3826     2331       2164
# G       314   871   4884     2924       2299
# H       303   702   3115     2360       1824
# I       175   522   2093     1428       1204
# J       119   307    896      808        678

# %%
plt.style.use('seaborn-darkgrid')
b=df_cut.plot(kind='bar',stacked=True,figsize=(10,10),xlabel='color',ylabel='cut')
for i in b.containers:
    variable=[j.get_height() if j.get_height()>0 else '' for j in i ]
    b.bar_label(i,labels=variable)
# Out:
# C:\Users\excel\AppData\Local\Temp\ipykernel_10116\3213208761.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [10, 20, 35, 45, 60]

# %%
plt.pie(x,labels=y);

# %%
df.hist('carat',bins=100,color='red',range=(0,3))
# Out:
# array([[<Axes: title={'center': 'carat'}>]], dtype=object)

# %%
df['carat'].shape
# Out:
# (53940,)

# %%
df.plot(kind='density',x='color',y='carat')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind='scatter',x='carat',y='price')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
df['carat'].value_counts()
# Out:
# carat
# 0.30    2604
# 0.31    2249
# 1.01    2242
# 0.70    1981
# 0.32    1840
#         ...
# 3.02       1
# 3.65       1
# 3.50       1
# 3.22       1
# 3.11       1
# Name: count, Length: 273, dtype: int64

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.boxplot('carat')
# Out:
# <Axes: >

# %%
df.boxplot('carat',by='color')
# Out:
# <Axes: title={'center': 'carat'}, xlabel='color'>

# %%
a=sns.countplot(data=df,x='color')
a.bar_label(a.containers[0]);

# %%
df['color'].value_counts()
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
sns.scatterplot(data=df,x='carat',y='price')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.boxplot(data=df,y='carat')
# Out:
# <Axes: ylabel='carat'>

# %%
df[['carat','price','x','y','z','table']].cov()
# Out:
#              carat         price            x            y            z  \
# carat     0.224687  1.742765e+03     0.518484     0.515248     0.318917
# price  1742.765364  1.591563e+07  3958.021491  3943.270810  2424.712613
# x         0.518484  3.958021e+03     1.258347     1.248789     0.768487
# y         0.515248  3.943271e+03     1.248789     1.304472     0.767320
# z         0.318917  2.424713e+03     0.768487     0.767320     0.498011
# table     0.192365  1.133318e+03     0.489643     0.468972     0.237996
#
#              table
# carat     0.192365
# price  1133.318064
# x         0.489643
# y         0.468972
# z         0.237996
# table     4.992948

# %%
sns.pairplot(df)
# Out:
# C:\Users\excel\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df[['carat','price']])
# Out:
# C:\Users\excel\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df[['carat','price','x','y','z']].corr()
# Out:
#           carat     price         x         y         z
# carat  1.000000  0.921591  0.975094  0.951722  0.953387
# price  0.921591  1.000000  0.884435  0.865421  0.861249
# x      0.975094  0.884435  1.000000  0.974701  0.970772
# y      0.951722  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.861249  0.970772  0.952006  1.000000

# %%
sns.heatmap(df[['carat','price','x','y','z']].corr(),annot=True,cmap='GnBu')
# Out:
# <Axes: >

# %%
sns.kdeplot(data=df,x='carat')
# Out:
# <Axes: xlabel='carat', ylabel='Density'>

# %%
df['carat'].unique()
# Out:
# array([0.23, 0.21, 0.29, 0.31, 0.24, 0.26, 0.22, 0.3 , 0.2 , 0.32, 0.33,
#        0.25, 0.35, 0.42, 0.28, 0.38, 0.7 , 0.86, 0.71, 0.78, 0.96, 0.73,
#        0.8 , 0.75, 0.74, 0.81, 0.59, 0.9 , 0.91, 0.61, 0.77, 0.63, 0.76,
#        0.64, 0.72, 0.79, 0.58, 1.17, 0.6 , 0.83, 0.54, 0.98, 0.52, 1.01,
#        0.53, 0.84, 0.51, 1.05, 0.55, 0.87, 1.  , 0.57, 0.82, 1.04, 0.93,
#        1.2 , 0.99, 0.34, 0.43, 0.36, 0.95, 0.89, 1.02, 0.97, 0.56, 0.85,
#        0.92, 1.27, 0.66, 1.12, 0.68, 1.03, 0.62, 1.22, 1.08, 0.88, 0.5 ,
#        1.19, 0.39, 0.65, 1.24, 1.5 , 0.27, 0.41, 1.13, 1.06, 0.69, 0.4 ,
#        1.14, 0.94, 1.29, 1.52, 1.16, 1.21, 1.23, 1.09, 0.67, 1.11, 1.1 ,
#        1.18, 1.15, 1.25, 1.07, 1.28, 1.51, 0.37, 1.31, 1.26, 1.39, 1.44,
#        1.35, 1.3 , 1.32, 1.41, 1.36, 1.45, 1.34, 1.58, 1.54, 1.38, 1.33,
#        1.74, 1.64, 1.47, 1.4 , 1.55, 1.95, 2.  , 1.37, 1.83, 1.62, 1.57,
#        1.69, 2.06, 1.72, 1.66, 2.14, 1.49, 1.46, 2.15, 1.96, 2.22, 1.7 ,
# ...

# %%
sns.distplot(df['carat'])
# Out:
# C:\Users\excel\AppData\Local\Temp\ipykernel_10116\943581646.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carat'])
# <Axes: xlabel='carat', ylabel='Density'>

# %%
lower_extreme= 126-(51*1.5)
lower_extreme
# Out:
# 49.5

# %%
upper_extreme= 177+(51*1.5)
upper_extreme
# Out:
# 253.5
